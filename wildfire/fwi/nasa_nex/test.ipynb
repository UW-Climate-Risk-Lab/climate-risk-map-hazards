# %%
import xarray as xr

# %%
ds = xr.load_dataset("s3://uw-crl/climate-risk-map/backend/climate/scenariomip/NEX-GDDP-CMIP6/ACCESS-CM2/historical/r1i1p1f1/fwi_day_ACCESS-CM2_historical_r1i1p1f1_gn_2014.zarr")

# %%
ds
# Out:
# <xarray.Dataset> Size: 392MB
# Dimensions:  (lat: 160, lon: 280, time: 365)
# Coordinates:
#   * lat      (lat) float64 1kB 10.12 10.38 10.62 10.88 ... 49.38 49.62 49.88
#   * lon      (lon) float64 2kB 230.1 230.4 230.6 230.9 ... 299.4 299.6 299.9
#   * time     (time) datetime64[ns] 3kB 2014-01-01T12:00:00 ... 2014-12-31T12:...
# Data variables:
#     bui      (lat, lon, time) float32 65MB nan nan nan nan ... nan nan nan nan
#     dc       (lat, lon, time) float32 65MB nan nan nan nan ... nan nan nan nan
#     dmc      (lat, lon, time) float32 65MB nan nan nan nan ... nan nan nan nan
#     ffmc     (lat, lon, time) float32 65MB nan nan nan nan ... nan nan nan nan
#     fwi      (lat, lon, time) float32 65MB nan nan nan nan ... nan nan nan nan
#     isi      (lat, lon, time) float32 65MB nan nan nan nan ... nan nan nan nan

# %%
ds.fwi.isel(time=230).plot()
